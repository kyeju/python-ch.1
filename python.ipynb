# %%
#Part1
scores = [56, 90, 78, 81]
count = 0
for score in scores:
    if score >= 80:
        count += 1
print(count)
# Out:
# 2

# %%
#Part2
sentence="""
파이썬 공부는 재미있다
파이썬 공부는 어렵지만 재미있다
데이터 분석에도 파이썬을 사용한다
파이썬 공부를 계속하면 실력이 늘어난다
"""
words = sentence.split()

word_counts = {}

for word in words:
    if word in word_counts:
        word_counts[word] += 1
    else:
        word_counts[word] = 1

print("전체 단어 빈도")
for word, count in word_counts.items():
    print(f"{word} : {count}회")

print("\n2회 이상 등장한 단어")
for word, count in word_counts.items():
    if count >= 2:
        print(f"{word} : {count}회")
# Out:
# 전체 단어 빈도
# 파이썬 : 3회
# 공부는 : 2회
# 재미있다 : 2회
# 어렵지만 : 1회
# 데이터 : 1회
# 분석에도 : 1회
# 파이썬을 : 1회
# 사용한다 : 1회
# 공부를 : 1회
# 계속하면 : 1회
# 실력이 : 1회
# 늘어난다 : 1회
#
# 2회 이상 등장한 단어
# 파이썬 : 3회
# 공부는 : 2회
# 재미있다 : 2회

# %%
#Part3
def count_words(sentence):
    words = sentence.split()
    word_counts = {}
    
    for word in words:
        if word in word_counts:
            word_counts[word] += 1
        else:
            word_counts[word] = 1
            
    return word_counts


def print_frequent_words(word_counts, min_count):
    print(f"\n{min_count}회 이상 등장한 단어")
    for word, count in word_counts.items():
        if count >= min_count:
            print(f"{word} : {count}회")


sentence = """
파이썬 공부는 재미있다
파이썬 공부는 어렵지만 재미있다
데이터 분석에도 파이썬을 사용한다
파이썬 공부를 계속하면 실력이 늘어난다
"""

result_counts = count_words(sentence)

print("전체 단어 빈도")
for word, count in result_counts.items():
    print(f"{word} : {count}회")

print_frequent_words(result_counts, 2)
# Out:
# 전체 단어 빈도
# 파이썬 : 3회
# 공부는 : 2회
# 재미있다 : 2회
# 어렵지만 : 1회
# 데이터 : 1회
# 분석에도 : 1회
# 파이썬을 : 1회
# 사용한다 : 1회
# 공부를 : 1회
# 계속하면 : 1회
# 실력이 : 1회
# 늘어난다 : 1회
#
# 2회 이상 등장한 단어
# 파이썬 : 3회
# 공부는 : 2회
# 재미있다 : 2회

# %%
#Part4 + 도전문제(특정 단어가 몇 번 등장했는지 검색하기)
def count_words(sentence):
    if not isinstance(sentence, str) or not sentence.strip():
        raise ValueError("입력값이 올바르지 않습니다.")
    
    words = sentence.split()
    word_counts = {}
    
    for word in words:
        if word in word_counts:
            word_counts[word] += 1
        else:
            word_counts[word] = 1
            
    return word_counts


def search_word(word_counts, target):
    return word_counts.get(target, 0)


sentence = """
파이썬 공부는 재미있다
파이썬 공부는 어렵지만 재미있다
데이터 분석에도 파이썬을 사용한다
파이썬 공부를 계속하면 실력이 늘어난다
"""

try:
    result_counts = count_words(sentence)
    
    print("전체 단어 빈도")
    for word, count in result_counts.items():
        print(f"{word} : {count}회")
        
    print("\n" + "=" * 30)
    search_target = input("검색할 단어를 입력하세요: ").strip()
    found_count = search_word(result_counts, search_target)
    
    print(f"'{search_target}' 단어 등장 횟수: {found_count}회")

except ValueError as e:
    print(f"오류 발생: {e}")
except Exception as e:
    print(f"알 수 없는 오류 발생: {e}")
# Out:
# 전체 단어 빈도
# 파이썬 : 3회
# 공부는 : 2회
# 재미있다 : 2회
# 어렵지만 : 1회
# 데이터 : 1회
# 분석에도 : 1회
# 파이썬을 : 1회
# 사용한다 : 1회
# 공부를 : 1회
# 계속하면 : 1회
# 실력이 : 1회
# 늘어난다 : 1회
#
# ...
# '파이썬' 단어 등장 횟수: 3회

# %% [markdown]
# ### 확인 질문
#
# 다음 질문에 본인의 말로 짧게 답변해주세요.
#
# 1. `for` 반복문은 이 프로그램에서 어떤 역할을 하나요?
#     ㄴ리스트 안 데이터 순회하며 꺼내오는 역할
# 2. 딕셔너리의 Key와 Value에는 각각 무엇이 저장되나요?
#     ㄴKey엔 중복되지 않는 단어가 저장되고 Value엔 단어가 등장한 횟수가 저장된다.
# 3. 같은 단어가 다시 등장하면 딕셔너리 값은 어떻게 달라지나요?
#     ㄴ기존 횟수에 1을 더해 누적 업데이트한다.
# 4. 함수를 사용하는 이유는 무엇인가요?
#     ㄴ코드 재사용성을 높이고 기준값만 바꿔 여러 번 호출하기에 용이하기에
# 5. AI를 사용했다면 AI가 제안한 코드에서 직접 확인하거나 수정한 부분은 무엇인가요?
#     ㄴpart2 if조건문부터 딕셔너리에 단어가 존재할 때와 처음 등장할 때를 나누는 if 조건문 및 함수 변수 전달 방식이 헷갈려 AI에게 힌트를 요청했고, 제안받은 in 키워드 기반 카운팅과 함수별 매개변수 구조를 직접 분석하며 단어 추출부터 예외 처리까지의 프로그램 전체 흐름을 이해하며 코드를 완성했습니다.
